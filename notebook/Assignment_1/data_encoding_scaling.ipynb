# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('../data/weather_features.csv')

df = pd.get_dummies(df, columns=['city_name', 'weather_main', 'weather_description'])

df.head()
# Out:
#                       dt_iso     temp  temp_min  temp_max  pressure  humidity  \
# 0  2015-01-01 00:00:00+01:00  270.475   270.475   270.475      1001        77
# 1  2015-01-01 01:00:00+01:00  270.475   270.475   270.475      1001        77
# 2  2015-01-01 02:00:00+01:00  269.686   269.686   269.686      1002        78
# 3  2015-01-01 03:00:00+01:00  269.686   269.686   269.686      1002        78
# 4  2015-01-01 04:00:00+01:00  269.686   269.686   269.686      1002        78
#
#    wind_speed  wind_deg  rain_1h  rain_3h  ...  \
# 0           1        62      0.0      0.0  ...
# 1           1        62      0.0      0.0  ...
# 2           0        23      0.0      0.0  ...
# 3           0        23      0.0      0.0  ...
# 4           0        23      0.0      0.0  ...
#
#    weather_description_sky is clear  weather_description_sleet  \
# 0                              True                      False
# 1                              True                      False
# ...
